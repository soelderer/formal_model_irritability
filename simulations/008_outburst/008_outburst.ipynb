# %% [markdown]
# # Simulation 8
# In Simulation 8, we extend the previous setup
# .........by adding response vigor as a downstream consequence of emotional intensity. As before, sadness is introduced as a negative emotion that emerges when outcomes are perceived as uncontrollable. We examine how anger/frustration and sadness vary as a function of perceived controllability, and how these emotions in turn modulate the vigor with which actions are executed.
#
# Using the same task structure as in Simulation 4, controllability is high in the first block and then declines in the second block. This decline follows a logistic function, allowing the researcher to tune both the midpoint and the rate of decay. The logistic form is chosen for pragmatic demonstration purposes and is not meant to imply a specific psychological inference mechanism.
#
# Response vigor is modeled as a bounded control signal that increases with the intensity of emotionally salient motive states, reflecting urgency and resource mobilization for action execution. Importantly, vigor does not affect action selection or learning in this simulation, but only the dynamics and intensity of responding.
#
# | Parameter | Range      | Interpretation |
# |-----------|------------|----------------|
# | η         | [0, 1]     | Learning rate: how quickly value expectations update |
# | γ         | [0, 1]     | Discount factor: weight given to future rewards |
# | λ_A       | [0, 1]     | Affective inertia: higher values → slower emotion updates |
# | α         | [0, 1]     | Relative weighting of prediction errors versus absolute rewards as affective inputs (1 … only RPE) |
# | κ         | > 1        | Negativity bias: negative affective inputs are amplified relative to positive ones |
# | λ_C       | [0, 1]     | Controllability learning rate: speed at which perceived controllability declines across trials in the uncontrollable block |
# | midpoint  | [100, 200] | Trial number at which C reaches 50% (inflection point of the decay) |
# | w_v_A     | >= 0       | Contribution of anger/frustration to response vigor |

# %%
n_iterations = 20

group_cols = ["lambda_A", "C", "eta", "gamma", "alpha",
              "kappa", "Step", "w_v_A", "I", "r1", "theta_N_w0",
              "theta_A_w0", "theta_A_w1", "V0", "M_A0", "M_S0"]

# %%
import model
import importlib
importlib.reload(model)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mesa.visualization import SolaraViz, SpaceRenderer, make_plot_component
from mesa import batch_run
import numpy as np
import gc
import sys


pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.options.display.float_format = "{:.3f}".format

init_variables = {
    # Variables

    "V0": [-0.5, 0, 0.5],
    "M_A0": [-0.5, 0, 0.5],  # anger
    "M_S0": [-0.5, 0, 0.5],  # sadness

    # Parameters

    # prior tendencies for neutral behavior
    "theta_N_w0": 2.944,  # should yield around 95% neutral in the beginning

    # prior tendencies for aggressive behavior
    "theta_A_w0": 0,
    "theta_A_w1": [-100, -80, -60, -40, -20, 0],

    # Parameter for the exponential moving average of anger
    "lambda_A": [8/9],  # plot for masters thesis (keeping values consistent)

    # Controllability
    "C": [1, 0.5, 0],

    # Learning rate
    "eta": [1/9,  # plot for masters thesis (keeping values consistent)
    ],  # parameter sweep

    # Discounting factor
    "gamma": [0,  # plot for masters thesis (keeping values consistent)
    ],  # parameter sweep

    # Balance between RPE and absolute rewards
    "alpha": [0, 1,
             4/9 # plot for masters thesis (keeping values consistent)
    ],

    # Negativity bias
    "kappa": [1.0,
              17/9], # plot for masters thesis (keeping values consistent)

    # Determines the impact of anger on vigor
    "w_v_A": [40/9],

    # Degree of response inhibition
    "I": [0, 0.5, 0.75],

    # Reward at time 1
    "r1": [0, -0.5, -1],
}

# We batch-run all parameter combinations.
# Because the model is stochastic, we run each combination multiple times
# (e.g., five iterations) to estimate the expected behavior.
# Seeding works as follows: each iteration is assigned a unique seed,
# and that same seed is used for all parameter combinations within that iteration.
# This ensures reproducibility while allowing multiple stochastic replications
# per parameter set.
rng = np.random.default_rng(12345)
seed_values = rng.integers(0, sys.maxsize, size=(n_iterations,))

for iteration, seed_value in enumerate(seed_values):
    print(f"Starting iteration {iteration}...", end="", flush=True)

    results = batch_run(
        model.IrritabilityModel,
        parameters=init_variables,
        data_collection_period=1,  # collect data for every step
        number_processes=16,
        rng=seed_value,
        max_steps=50,
    )

    results_df = pd.DataFrame(results)
    results_df["iteration"] = iteration

    # Sorting allows for row-based aggregation later
    results_df = results_df.sort_values(group_cols, ignore_index=True)

    results_df.to_parquet(f"output/008_outburst_{iteration}.parquet")

    del results
    del results_df
    gc.collect()

    print(f"Starting iteration {iteration}... done.")

# Quick test of sorting
df7 = pd.read_parquet("output/008_outburst_7.parquet", columns=group_cols)
df14 = pd.read_parquet("output/008_outburst_14.parquet", columns=group_cols)
assert df7.equals(df14), "Rows do not align after sorting!"

del df7, df14
gc.collect()
# Out:
# Starting iteration 0...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 0... done.
# Starting iteration 1...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 1... done.
# Starting iteration 2...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 2... done.
# Starting iteration 3...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 3... done.
# Starting iteration 4...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 4... done.
# Starting iteration 5...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 5... done.
# Starting iteration 6...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 6... done.
# Starting iteration 7...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 7... done.
# Starting iteration 8...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 8... done.
# Starting iteration 9...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 9... done.
# Starting iteration 10...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 10... done.
# Starting iteration 11...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 11... done.
# Starting iteration 12...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 12... done.
# Starting iteration 13...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 13... done.
# Starting iteration 14...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 14... done.
# Starting iteration 15...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 15... done.
# Starting iteration 16...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 16... done.
# Starting iteration 17...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 17... done.
# Starting iteration 18...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 18... done.
# Starting iteration 19...
#   0%|          | 0/26244 [00:00<?, ?it/s]
# Starting iteration 19... done.
# 0

# %% [markdown]
# ## Summary (expectation and standard errors)

# %%
import numpy as np

value_cols = ["V", "M_A", "M_S", "v", "p_A"]

n_rows = len(pd.read_parquet("output/008_outburst_0.parquet"))
n = 0
mean = {col: np.zeros(n_rows) for col in value_cols}
M2 = {col: np.zeros(n_rows) for col in value_cols}

for i in range(n_iterations):
    path = f"output/008_outburst_{i}.parquet"

    print(f"Processing iteration {i}...")

    df = pd.read_parquet(path, columns=value_cols)
    n += 1
    for c in value_cols:
        x = df[c].to_numpy()
        delta = x - mean[c]
        mean[c] += delta / n
        M2[c] += delta * (x - mean[c])

# final standard deviation
std = {c: np.sqrt(M2[c] / (n - 1)) for c in value_cols}

df = pd.read_parquet(
    "output/008_outburst_0.parquet",
    columns=group_cols
)

summary = df.copy()

for c in value_cols:
    summary[f"{c}_mean"] = mean[c]
    summary[f"{c}_std"] = std[c]

summary.to_parquet("output/008_outburst_summary.parquet")
# Out:
# Processing iteration 0...
# Processing iteration 1...
# Processing iteration 2...
# Processing iteration 3...
# Processing iteration 4...
# Processing iteration 5...
# Processing iteration 6...
# Processing iteration 7...
# Processing iteration 8...
# Processing iteration 9...
# Processing iteration 10...
# Processing iteration 11...
# Processing iteration 12...
# Processing iteration 13...
# Processing iteration 14...
# Processing iteration 15...
# Processing iteration 16...
# Processing iteration 17...
# Processing iteration 18...
# Processing iteration 19...

# %% [markdown]
# # Downcast data for dashboard

# %%
import pandas as pd
import gc

# Summary dataframe

summary = pd.read_parquet("output/008_outburst_summary.parquet")

summary.info(memory_usage="deep")

for c in summary.select_dtypes(include="integer"):
    summary[c] = pd.to_numeric(summary[c], downcast="integer")

for c in summary.select_dtypes(include="float"):
    summary[c] = pd.to_numeric(summary[c], downcast="float")

summary.info(memory_usage="deep")

summary.to_parquet("output/dashboard/008_outburst_summary.parquet")

# Write meta-info
lambda_A_vals = sorted(summary["lambda_A"].unique())
eta_vals      = sorted(summary["eta"].unique())
gamma_vals    = sorted(summary["gamma"].unique())
C_vals        = sorted(summary["C"].unique())
alpha_vals        = sorted(summary["alpha"].unique())
kappa_vals        = sorted(summary["kappa"].unique())
w_v_A_vals        = sorted(summary["w_v_A"].unique())
I_vals        = sorted(summary["I"].unique())
r1_vals        = sorted(summary["r1"].unique())
V0_vals        = sorted(summary["V0"].unique())
M_A0_vals        = sorted(summary["M_A0"].unique())
M_S0_vals        = sorted(summary["M_S0"].unique())
theta_N_w0_vals        = sorted(summary["theta_N_w0"].unique())
theta_A_w0_vals        = sorted(summary["theta_A_w0"].unique())
theta_A_w1_vals        = sorted(summary["theta_A_w1"].unique())

meta_df = pd.DataFrame({
    "n_iterations": [n_iterations],
    "lambda_A_vals": [lambda_A_vals],
    "eta_vals": [eta_vals],
    "gamma_vals": [gamma_vals],
    "C_vals": [C_vals],
    "alpha_vals": [alpha_vals],
    "kappa_vals": [kappa_vals],
    "r1_vals": [r1_vals],
    "V0_vals": [V0_vals],
    "M_A0_vals": [M_A0_vals],
    "M_S0_vals": [M_S0_vals],
    "theta_N_w0_vals": [theta_N_w0_vals],
    "theta_A_w0_vals": [theta_A_w0_vals],
    "theta_A_w1_vals": [theta_A_w1_vals],
    "w_v_A_vals": [w_v_A_vals],
    "I_vals": [I_vals]
})

# Write to parquet
meta_df.to_parquet("output/dashboard/meta_info.parquet",
                   engine="pyarrow")

del summary
gc.collect()

# Individual iterations
n_iterations_dashboard = 3  # not all iterations to save memory

for i in range(n_iterations_dashboard):
    print("-------------------------------------------------------------------")

    df = pd.read_parquet(f"output/008_outburst_{i}.parquet")

    df.info(memory_usage="deep")

    df.drop(columns=["AgentID", "RunId", "iteration", "seed"],
            inplace=True)

    for c in df.select_dtypes(include="integer"):
        df[c] = pd.to_numeric(df[c], downcast="integer")

    for c in df.select_dtypes(include="float"):
        df[c] = pd.to_numeric(df[c], downcast="float")

    df.info(memory_usage="deep")

    df.to_parquet(f"output/dashboard/008_outburst_{i}.parquet")

    del df
    gc.collect()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 26 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   lambda_A    1338444 non-null  float64
#  1   C           1338444 non-null  float64
#  2   eta         1338444 non-null  float64
#  3   gamma       1338444 non-null  int64
#  4   alpha       1338444 non-null  float64
#  5   kappa       1338444 non-null  float64
#  6   Step        1338444 non-null  int64
#  7   w_v_A       1338444 non-null  float64
#  8   I           1338444 non-null  float64
#  9   r1          1338444 non-null  float64
#  10  theta_N_w0  1338444 non-null  float64
#  11  theta_A_w0  1338444 non-null  int64
#  12  theta_A_w1  1338444 non-null  int64
#  13  V0          1338444 non-null  float64
#  14  M_A0        1338444 non-null  float64
#  15  M_S0        1338444 non-null  float64
#  16  V_mean      1312200 non-null  float64
#  17  V_std       1312200 non-null  float64
#  18  M_A_mean    1312200 non-null  float64
#  19  M_A_std     1312200 non-null  float64
#  20  M_S_mean    1312200 non-null  float64
#  21  M_S_std     1312200 non-null  float64
#  22  v_mean      1312200 non-null  float64
#  23  v_std       1312200 non-null  float64
#  24  p_A_mean    1312200 non-null  float64
#  25  p_A_std     1312200 non-null  float64
# dtypes: float64(22), int64(4)
# memory usage: 265.5 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 26 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   lambda_A    1338444 non-null  float32
#  1   C           1338444 non-null  float32
#  2   eta         1338444 non-null  float32
#  3   gamma       1338444 non-null  int8
#  4   alpha       1338444 non-null  float32
#  5   kappa       1338444 non-null  float32
#  6   Step        1338444 non-null  int8
#  7   w_v_A       1338444 non-null  float32
#  8   I           1338444 non-null  float32
#  9   r1          1338444 non-null  float32
#  10  theta_N_w0  1338444 non-null  float32
#  11  theta_A_w0  1338444 non-null  int8
#  12  theta_A_w1  1338444 non-null  int8
#  13  V0          1338444 non-null  float32
#  14  M_A0        1338444 non-null  float32
#  15  M_S0        1338444 non-null  float32
#  16  V_mean      1312200 non-null  float32
#  17  V_std       1312200 non-null  float32
#  18  M_A_mean    1312200 non-null  float32
#  19  M_A_std     1312200 non-null  float32
#  20  M_S_mean    1312200 non-null  float32
#  21  M_S_std     1312200 non-null  float32
#  22  v_mean      1312200 non-null  float32
#  23  v_std       1312200 non-null  float32
#  24  p_A_mean    1312200 non-null  float32
#  25  p_A_std     1312200 non-null  float32
# dtypes: float32(22), int8(4)
# memory usage: 117.4 MB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 31 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   RunId       1338444 non-null  int64
#  1   iteration   1338444 non-null  int64
#  2   Step        1338444 non-null  int64
#  3   V0          1338444 non-null  float64
#  4   M_A0        1338444 non-null  float64
#  5   M_S0        1338444 non-null  float64
#  6   theta_N_w0  1338444 non-null  float64
#  7   theta_A_w0  1338444 non-null  int64
#  8   theta_A_w1  1338444 non-null  int64
#  9   lambda_A    1338444 non-null  float64
#  10  C           1338444 non-null  float64
#  11  eta         1338444 non-null  float64
#  12  gamma       1338444 non-null  int64
#  13  alpha       1338444 non-null  float64
#  14  kappa       1338444 non-null  float64
#  15  w_v_A       1338444 non-null  float64
#  16  I           1338444 non-null  float64
#  17  r1          1338444 non-null  float64
#  18  seed        1338444 non-null  int64
#  19  AgentID     1312200 non-null  float64
#  20  V           1312200 non-null  float64
#  21  M_A         1312200 non-null  float64
#  22  M_S         1312200 non-null  float64
#  23  r           1312200 non-null  float64
#  24  rpe         1312200 non-null  float64
#  25  v           1312200 non-null  float64
#  26  theta_N     1312200 non-null  float64
#  27  theta_A     1312200 non-null  float64
#  28  p_N         1312200 non-null  float64
#  29  p_A         1312200 non-null  float64
#  30  a           1312200 non-null  str
# dtypes: float64(23), int64(7), str(1)
# memory usage: 326.1 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 27 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Step        1338444 non-null  int8
#  1   V0          1338444 non-null  float32
#  2   M_A0        1338444 non-null  float32
#  3   M_S0        1338444 non-null  float32
#  4   theta_N_w0  1338444 non-null  float32
#  5   theta_A_w0  1338444 non-null  int8
#  6   theta_A_w1  1338444 non-null  int8
#  7   lambda_A    1338444 non-null  float32
#  8   C           1338444 non-null  float32
#  9   eta         1338444 non-null  float32
#  10  gamma       1338444 non-null  int8
#  11  alpha       1338444 non-null  float32
#  12  kappa       1338444 non-null  float32
#  13  w_v_A       1338444 non-null  float32
#  14  I           1338444 non-null  float32
#  15  r1          1338444 non-null  float32
#  16  V           1312200 non-null  float32
#  17  M_A         1312200 non-null  float32
#  18  M_S         1312200 non-null  float32
#  19  r           1312200 non-null  float32
#  20  rpe         1312200 non-null  float32
#  21  v           1312200 non-null  float32
#  22  theta_N     1312200 non-null  float32
#  23  theta_A     1312200 non-null  float32
#  24  p_N         1312200 non-null  float32
#  25  p_A         1312200 non-null  float32
#  26  a           1312200 non-null  str
# dtypes: float32(22), int8(4), str(1)
# memory usage: 137.2 MB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 31 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   RunId       1338444 non-null  int64
#  1   iteration   1338444 non-null  int64
#  2   Step        1338444 non-null  int64
#  3   V0          1338444 non-null  float64
#  4   M_A0        1338444 non-null  float64
#  5   M_S0        1338444 non-null  float64
#  6   theta_N_w0  1338444 non-null  float64
#  7   theta_A_w0  1338444 non-null  int64
#  8   theta_A_w1  1338444 non-null  int64
#  9   lambda_A    1338444 non-null  float64
#  10  C           1338444 non-null  float64
#  11  eta         1338444 non-null  float64
#  12  gamma       1338444 non-null  int64
#  13  alpha       1338444 non-null  float64
#  14  kappa       1338444 non-null  float64
#  15  w_v_A       1338444 non-null  float64
#  16  I           1338444 non-null  float64
#  17  r1          1338444 non-null  float64
#  18  seed        1338444 non-null  int64
#  19  AgentID     1312200 non-null  float64
#  20  V           1312200 non-null  float64
#  21  M_A         1312200 non-null  float64
#  22  M_S         1312200 non-null  float64
#  23  r           1312200 non-null  float64
#  24  rpe         1312200 non-null  float64
#  25  v           1312200 non-null  float64
#  26  theta_N     1312200 non-null  float64
#  27  theta_A     1312200 non-null  float64
#  28  p_N         1312200 non-null  float64
#  29  p_A         1312200 non-null  float64
#  30  a           1312200 non-null  str
# dtypes: float64(23), int64(7), str(1)
# memory usage: 326.1 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 27 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Step        1338444 non-null  int8
#  1   V0          1338444 non-null  float32
#  2   M_A0        1338444 non-null  float32
#  3   M_S0        1338444 non-null  float32
#  4   theta_N_w0  1338444 non-null  float32
#  5   theta_A_w0  1338444 non-null  int8
#  6   theta_A_w1  1338444 non-null  int8
#  7   lambda_A    1338444 non-null  float32
#  8   C           1338444 non-null  float32
#  9   eta         1338444 non-null  float32
#  10  gamma       1338444 non-null  int8
#  11  alpha       1338444 non-null  float32
#  12  kappa       1338444 non-null  float32
#  13  w_v_A       1338444 non-null  float32
#  14  I           1338444 non-null  float32
#  15  r1          1338444 non-null  float32
#  16  V           1312200 non-null  float32
#  17  M_A         1312200 non-null  float32
#  18  M_S         1312200 non-null  float32
#  19  r           1312200 non-null  float32
#  20  rpe         1312200 non-null  float32
#  21  v           1312200 non-null  float32
#  22  theta_N     1312200 non-null  float32
#  23  theta_A     1312200 non-null  float32
#  24  p_N         1312200 non-null  float32
#  25  p_A         1312200 non-null  float32
#  26  a           1312200 non-null  str
# dtypes: float32(22), int8(4), str(1)
# memory usage: 137.2 MB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 31 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   RunId       1338444 non-null  int64
#  1   iteration   1338444 non-null  int64
#  2   Step        1338444 non-null  int64
#  3   V0          1338444 non-null  float64
#  4   M_A0        1338444 non-null  float64
#  5   M_S0        1338444 non-null  float64
#  6   theta_N_w0  1338444 non-null  float64
#  7   theta_A_w0  1338444 non-null  int64
#  8   theta_A_w1  1338444 non-null  int64
#  9   lambda_A    1338444 non-null  float64
#  10  C           1338444 non-null  float64
#  11  eta         1338444 non-null  float64
#  12  gamma       1338444 non-null  int64
#  13  alpha       1338444 non-null  float64
#  14  kappa       1338444 non-null  float64
#  15  w_v_A       1338444 non-null  float64
#  16  I           1338444 non-null  float64
#  17  r1          1338444 non-null  float64
#  18  seed        1338444 non-null  int64
#  19  AgentID     1312200 non-null  float64
#  20  V           1312200 non-null  float64
#  21  M_A         1312200 non-null  float64
#  22  M_S         1312200 non-null  float64
#  23  r           1312200 non-null  float64
#  24  rpe         1312200 non-null  float64
#  25  v           1312200 non-null  float64
#  26  theta_N     1312200 non-null  float64
#  27  theta_A     1312200 non-null  float64
#  28  p_N         1312200 non-null  float64
#  29  p_A         1312200 non-null  float64
#  30  a           1312200 non-null  str
# dtypes: float64(23), int64(7), str(1)
# memory usage: 326.3 MB
# <class 'pandas.DataFrame'>
# RangeIndex: 1338444 entries, 0 to 1338443
# Data columns (total 27 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Step        1338444 non-null  int8
#  1   V0          1338444 non-null  float32
#  2   M_A0        1338444 non-null  float32
#  3   M_S0        1338444 non-null  float32
#  4   theta_N_w0  1338444 non-null  float32
#  5   theta_A_w0  1338444 non-null  int8
#  6   theta_A_w1  1338444 non-null  int8
#  7   lambda_A    1338444 non-null  float32
#  8   C           1338444 non-null  float32
#  9   eta         1338444 non-null  float32
#  10  gamma       1338444 non-null  int8
#  11  alpha       1338444 non-null  float32
#  12  kappa       1338444 non-null  float32
#  13  w_v_A       1338444 non-null  float32
#  14  I           1338444 non-null  float32
#  15  r1          1338444 non-null  float32
#  16  V           1312200 non-null  float32
#  17  M_A         1312200 non-null  float32
#  18  M_S         1312200 non-null  float32
#  19  r           1312200 non-null  float32
#  20  rpe         1312200 non-null  float32
#  21  v           1312200 non-null  float32
#  22  theta_N     1312200 non-null  float32
#  23  theta_A     1312200 non-null  float32
#  24  p_N         1312200 non-null  float32
#  25  p_A         1312200 non-null  float32
#  26  a           1312200 non-null  str
# dtypes: float32(22), int8(4), str(1)
# memory usage: 137.3 MB
