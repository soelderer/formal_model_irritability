# %% [markdown]
# # Simulation 5
# In Simulation 5, we extend the previous setup by adding response vigor as a downstream consequence of emotional intensity. As before, sadness is introduced as a negative emotion that emerges when outcomes are perceived as uncontrollable. We examine how anger/frustration and sadness vary as a function of perceived controllability, and how these emotions in turn modulate the vigor with which actions are executed.
#
# Using the same task structure as in Simulation 4, controllability is high in the first block and then declines in the second block. This decline follows a logistic function, allowing the researcher to tune both the midpoint and the rate of decay. The logistic form is chosen for pragmatic demonstration purposes and is not meant to imply a specific psychological inference mechanism.
#
# Response vigor is modeled as a bounded control signal that increases with the intensity of emotionally salient motive states, reflecting urgency and resource mobilization for action execution. Importantly, vigor does not affect action selection or learning in this simulation, but only the dynamics and intensity of responding.
#
# | Parameter | Range      | Interpretation |
# |-----------|------------|----------------|
# | η         | [0, 1]     | Learning rate: how quickly value expectations update |
# | γ         | [0, 1]     | Discount factor: weight given to future rewards |
# | λ_A       | [0, 1]     | Affective inertia: higher values → slower emotion updates |
# | α         | [0, 1]     | Relative weighting of prediction errors versus absolute rewards as affective inputs (1 … only RPE) |
# | κ         | > 1        | Negativity bias: negative affective inputs are amplified relative to positive ones |
# | λ_C       | [0, 1]     | Controllability learning rate: speed at which perceived controllability declines across trials in the uncontrollable block |
# | midpoint  | [100, 200] | Trial number at which C reaches 50% (inflection point of the decay) |
# | w_v_A     | >= 0       | Contribution of anger/frustration to response vigor |

# %%
n_iterations = 20

group_cols = ["lambda_A", "C", "eta", "gamma", "alpha", "kappa", "Step", "w_v_A"]

# %%
import model
import importlib
importlib.reload(model)
import agents
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mesa.visualization import SolaraViz, SpaceRenderer, make_plot_component
from mesa import batch_run
import numpy as np
import gc
import sys


pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.options.display.float_format = "{:.3f}".format

init_variables = {
    # Variables

    "environment_type":
        model.IrritabilityModel.EnvironmentType.EnvironmentNeutral,

    "S": agents.IrritabilityAgent.State.GOAL_NOT_REQUESTED,
    "V_NR": 0,
    "V_DE": 0,
    "V_AB": 0,
    "V_GR": 0,
    "M_A": 0,  # anger
    "M_S": 0,  # sadness

    "theta_N_w0": 0,
    "theta_F_w0": 0,
    "theta_A_w0": 0,
    "theta_A_w1": 0,
    "theta_E_w0": 0,

    # Parameters

    "C": 1.0,

    # Parameter for the exponential moving average of anger
    # "lambda_A": np.linspace(0.8, 1, 5),
    "lambda_A": 0.9,

    # Learning rate
    # "eta": np.linspace(0, 1, 5),
    "eta": 0.25,

    # Discounting factor
    "gamma": 0.9,

    # Balance between RPE and absolute rewards
    "alpha": 0.5,

    # Negativity bias
    "kappa": 4.0,

    # Determines the impact of anger on vigor
    "w_v_A": 4.0
}

# We batch-run all parameter combinations.
# Because the model is stochastic, we run each combination multiple times
# (e.g., five iterations) to estimate the expected behavior.
# Seeding works as follows: each iteration is assigned a unique seed,
# and that same seed is used for all parameter combinations within that iteration.
# This ensures reproducibility while allowing multiple stochastic replications
# per parameter set.
rng = np.random.default_rng(12345)
seed_values = rng.integers(0, sys.maxsize, size=(n_iterations,))

for iteration, seed_value in enumerate(seed_values):
    print(f"Starting iteration {iteration}...", end="", flush=True)

    results = batch_run(
        model.IrritabilityModel,
        parameters=init_variables,
        data_collection_period=1,  # collect data for every step
        number_processes=16,
        rng=seed_value,
        max_steps=200,
    )

    results_df = pd.DataFrame(results)
    results_df["iteration"] = iteration

    # Sorting allows for row-based aggregation later
    results_df = results_df.sort_values(group_cols, ignore_index=True)

    display(results_df)

    results_df.to_parquet(f"output/100_request_{iteration}.parquet")

    del results
    del results_df
    gc.collect()

    print(f"Starting iteration {iteration}... done.")

# Quick test of sorting
df7 = pd.read_parquet("output/100_request_7.parquet", columns=group_cols)
df14 = pd.read_parquet("output/100_request_14.parquet", columns=group_cols)
assert df7.equals(df14), "Rows do not align after sorting!"

del df7, df14
gc.collect()
# Out:
# Starting iteration 0...
#   0%|          | 0/1 [00:00<?, ?it/s]
# {'S': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f980ba33c40>, 'V_NR': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f98366e8fe0>, 'V_DE': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97dd579d00>, 'V_AB': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6700>, 'V_GR': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d67a0>, 'M_A': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6840>, 'M_S': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d68e0>, 'r': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6980>, 'rpe': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6a20>, 'v': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6ac0>, 'theta_N_w0': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6b60>, 'theta_N': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6c00>, 'theta_F_w0': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6ca0>, 'theta_F': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6d40>, 'theta_A_w0': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6de0>, 'theta_A_w1': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6e80>, 'theta_A': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6f20>, 'theta_E_w0': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d6fc0>, 'theta_E': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7060>, 'p_N': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7100>, 'p_F': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d71a0>, 'p_A': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7240>, 'a': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d72e0>, 'lambda_A': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7380>, 'C': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7420>, 'eta': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d74c0>, 'gamma': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7560>, 'alpha': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7600>, 'kappa': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d76a0>, 'w_v_A': <function IrritabilityModel.__init__.<locals>.<lambda> at 0x7f97d52d7740>}
# model step 1
# telling agents to choose_action_and_act()
# State: State.GOAL_NOT_REQUESTED
# Chose action: REQUEST_AGGRESSIVELY
# act REQUEST_AGGRESSIVELY: get_state_value()
# Getting state value of State.GOAL_NOT_REQUESTED...
# self._S_new: State.GOAL_GRANTED
# reward: 1.0
# telling agents to update_emotions_and_learn()
# learning state value...
# Getting state value of State.GOAL_NOT_REQUESTED...
# telling agents to transit_state()
# model step 2
# reached a terminal state
#    RunId  iteration  Step                    environment_type  \
# 0      0          0     0  EnvironmentType.EnvironmentNeutral
# 1      0          0     1  EnvironmentType.EnvironmentNeutral
# 2      0          0     2  EnvironmentType.EnvironmentNeutral
#
#                           S  V_NR  V_DE  V_AB  V_GR   M_A   M_S  theta_N_w0  \
# 0  State.GOAL_NOT_REQUESTED 0.000     0     0     0 0.000 0.000           0
# 1        GOAL_NOT_REQUESTED 0.000     0     0     0 0.000 0.000           0
# 2              GOAL_GRANTED 0.250     0     0     0 0.100 0.000           0
#
#    theta_F_w0  theta_A_w0  theta_A_w1  theta_E_w0     C  lambda_A   eta  \
# 0           0           0           0           0 1.000     0.900 0.250
# 1           0           0           0           0 1.000     0.900 0.250
# 2           0           0           0           0 1.000     0.900 0.250
#
#    gamma  alpha  kappa  w_v_A                 seed  AgentID     r   rpe     v  \
# 0  0.900  0.500  4.000  4.000  2096804712593481934      NaN   NaN   NaN   NaN
# 1  0.900  0.500  4.000  4.000  2096804712593481934    1.000 1.000 1.000 0.500
# 2  0.900  0.500  4.000  4.000  2096804712593481934    1.000 1.000 1.000 0.500
#
#    theta_N  theta_F  theta_A  theta_E   p_N   p_F   p_A                     a
# 0      NaN      NaN      NaN      NaN   NaN   NaN   NaN                   NaN
# 1    0.000    0.000    0.000    0.000 0.250 0.250 0.250  REQUEST_AGGRESSIVELY
# 2    0.000    0.000    0.000    0.000 0.250 0.250 0.250  REQUEST_AGGRESSIVELY
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[2], line 96
#      92 results_df = results_df.sort_values(group_cols, ignore_index=True)
#      94 display(results_df)
# ---> 96 results_df.to_parquet(f"output/100_request_{iteration}.parquet")
#      98 del results
#      99 del results_df
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pandas/io/parquet.py:490, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 490 impl.write(
#     491     df,
#     492     path_or_buf,
#     493     compression=compression,
#     494     index=index,
#     495     partition_cols=partition_cols,
#     496     storage_options=storage_options,
#     497     filesystem=filesystem,
#     498     **kwargs,
#     499 )
#     501 if path is None:
#     502     assert isinstance(path_or_buf, io.BytesIO)
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pandas/io/parquet.py:191, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     188 if index is not None:
#     189     from_pandas_kwargs["preserve_index"] = index
# --> 191 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     193 if df.attrs:
#     194     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/table.pxi:4796, in pyarrow.lib.Table.from_pandas()
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/pandas_compat.py:651, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     646     return (isinstance(arr, np.ndarray) and
#     647             arr.flags.contiguous and
#     648             issubclass(arr.dtype.type, np.integer))
#     650 if nthreads == 1:
# --> 651     arrays = [convert_column(c, f)
#     652               for c, f in zip(columns_to_convert, convert_fields)]
#     653 else:
#     654     arrays = []
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/pandas_compat.py:639, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
# --> 639     raise e
#     640 if not field_nullable and result.null_count > 0:
#     641     raise ValueError(f"Field {field} was non-nullable but pandas column "
#     642                      f"had {result.null_count} null values")
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/pandas_compat.py:633, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     630     type_ = field.type
#     632 try:
# --> 633     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/array.pxi:365, in pyarrow.lib.array()
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/array.pxi:91, in pyarrow.lib._ndarray_to_array()
#
# File ~/.conda/envs/irritability_simulations/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: ('Could not convert <EnvironmentType.EnvironmentNeutral: 1> with type EnvironmentType: did not recognize Python value type when inferring an Arrow data type', 'Conversion failed for column environment_type with type object')

# %%
results
# Out:
# [{'RunId': 0,
#   'iteration': 0,
#   'Step': 0,
#   'environment_type': <EnvironmentType.EnvironmentNeutral: 1>,
#   'S': <State.GOAL_NOT_REQUESTED: 1>,
#   'V_NR': 0,
#   'V_DE': 0,
#   'V_AB': 0,
#   'V_GR': 0,
#   'M_A': 0,
#   'M_S': 0,
#   'theta_N_w0': 0,
#   'theta_F_w0': 0,
#   'theta_A_w0': 0,
#   'theta_A_w1': 0,
#   'theta_E_w0': 0,
#   'C': 1.0,
#   'lambda_A': 0.9,
#   'eta': 0.25,
#   'gamma': 0.9,
#   'alpha': 0.5,
#   'kappa': 4.0,
#   'w_v_A': 4.0,
#   'seed': np.int64(2096804712593481934)}]

# %% [markdown]
# ## Summary (expectation and standard errors)

# %%
df = pd.read_parquet("output/005_response_vigor_0.parquet")

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_parquet("output/005_response_vigor_0.parquet")
#       3 df.head()
#
# NameError: name 'pd' is not defined

# %%
import numpy as np

value_cols = ["V", "M_A", "M_S", "v"]

n_rows = len(pd.read_parquet("output/005_response_vigor_0.parquet"))
n = 0
mean = {col: np.zeros(n_rows) for col in value_cols}
M2 = {col: np.zeros(n_rows) for col in value_cols}

for i in range(n_iterations):
    path = f"output/005_response_vigor_{i}.parquet"

    print(f"Processing iteration {i}...")

    df = pd.read_parquet(path, columns=value_cols)
    n += 1
    for c in value_cols:
        x = df[c].to_numpy()
        delta = x - mean[c]
        mean[c] += delta / n
        M2[c] += delta * (x - mean[c])

# final standard deviation
std = {c: np.sqrt(M2[c] / (n - 1)) for c in value_cols}

df = pd.read_parquet(
    "output/005_response_vigor_0.parquet",
    columns=group_cols
)

summary = df.copy()

for c in value_cols:
    summary[f"{c}_mean"] = mean[c]
    summary[f"{c}_std"] = std[c]

summary.to_parquet("output/005_response_vigor_summary.parquet")

# %% [markdown]
# # Downcast data for dashboard

# %%
import pandas as pd
import gc

# Summary dataframe

summary = pd.read_parquet("output/005_response_vigor_summary.parquet")

summary.info(memory_usage="deep")

for c in summary.select_dtypes(include="integer"):
    summary[c] = pd.to_numeric(summary[c], downcast="integer")

for c in summary.select_dtypes(include="float"):
    summary[c] = pd.to_numeric(summary[c], downcast="float")

summary.info(memory_usage="deep")

summary.to_parquet("output/dashboard/005_response_vigor_summary.parquet")

# Write meta-info
lambda_A_vals = sorted(summary["lambda_A"].unique())
lambda_C_vals = sorted(summary["lambda_C"].unique())
midpoint_vals = sorted(summary["midpoint"].unique())
eta_vals      = sorted(summary["eta"].unique())
gamma_vals    = sorted(summary["gamma"].unique())
C_vals        = sorted(summary["C"].unique())
alpha_vals        = sorted(summary["alpha"].unique())
kappa_vals        = sorted(summary["kappa"].unique())
w_v_A_vals        = sorted(summary["w_v_A"].unique())

meta_df = pd.DataFrame({
    "n_iterations": [n_iterations],
    "lambda_A_vals": [lambda_A_vals],
    "eta_vals": [eta_vals],
    "gamma_vals": [gamma_vals],
    "C_vals": [C_vals],
    "alpha_vals": [alpha_vals],
    "kappa_vals": [kappa_vals],
    "lambda_C_vals": [lambda_C_vals],
    "midpoint_vals": [midpoint_vals],
    "w_v_A_vals": [w_v_A_vals]
})

# Write to parquet
meta_df.to_parquet("output/dashboard/meta_info.parquet",
                   engine="pyarrow")

del summary
gc.collect()

# Individual iterations
n_iterations_dashboard = 3  # not all iterations to save memory

for i in range(n_iterations_dashboard):
    print("-------------------------------------------------------------------")

    df = pd.read_parquet(f"output/005_response_vigor_{i}.parquet")

    df.info(memory_usage="deep")

    df.drop(columns=["AgentID", "RunId", "iteration", "r", "rpe", "seed"],
            inplace=True)

    for c in df.select_dtypes(include="integer"):
        df[c] = pd.to_numeric(df[c], downcast="integer")

    for c in df.select_dtypes(include="float"):
        df[c] = pd.to_numeric(df[c], downcast="float")

    df.info(memory_usage="deep")

    df.to_parquet(f"output/dashboard/005_response_vigor_{i}.parquet")

    del df
    gc.collect()

# %% [markdown]
# # A glimpse at the data

# %%
print(results_df["C"].unique())

# results1 = results_df[results_df["RunId"] == 230]

# gamma = 0.57894737
# eta = 0.05263158
# lambda_A = 0.15789474
# C = 1

results1 = results_df[
    np.isclose(results_df["gamma"], 0.57894737) &
    np.isclose(results_df["eta"], 0.05263158) &
    np.isclose(results_df["lambda_A"], 0.84210526) &
    np.isclose(results_df["C"], 1)
]

# print(results_df.loc[22826, "eta"], repr(results_df.loc[22826, "eta"]))
# print(results_df.loc[22826, "lambda_A"], repr(results_df.loc[22826, "lambda_A"]))
# print(results_df.loc[22826, "C"], repr(results_df.loc[22826, "C"]))

# print(results_df["gamma"].dtype)


# results1.head(n=200)

# Prior to the first step, many things are not defined (e.g. action)
# results_df = results_df[results_df["Step"] > 0]

# results_df.head(n=200)

# results_df.columns

# %% [markdown]
# # Some plots

# %%
g = sns.lineplot(data=results1,
                 y="V",
                 x="Step",
                 label="Value of state")

g = sns.lineplot(data=results1,
                 y=results1["M_A"],
                 x="Step",
                 color="Orange",
                 label="Anger/frustration")

# g.set(title="Anger and aggressive action",
#       ylabel="Value");
plt.axhline(y=0, color='black', linewidth=1)
plt.axvline(x=100, color='black', linewidth=1, linestyle="--")

# plt.xlim(0, 130)
# plt.ylim(0, 1)
plt.show()
