# %%
n_iterations = 20

group_cols = ["lambda_A", "lambda_C", "midpoint", "C", "eta", "gamma", "alpha",
              "kappa", "Step"]

# %%
import model
import importlib
importlib.reload(model)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mesa.visualization import SolaraViz, SpaceRenderer, make_plot_component
from mesa import batch_run
import numpy as np
import gc
import sys


pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.width", None)
pd.options.display.float_format = "{:.3f}".format

init_variables = {
    # Variables

    "V": 0,
    "M_A": 0,  # anger
    "M_S": 0,  # sadness

    # Some variables will be calculated in the model
    # or received from the environment
    "r": None,
    "rpe": None,

    "C": None,

    # Parameters

    # Parameter for the exponential moving average of anger
    "lambda_A": np.linspace(0, 1, 10),
    "lambda_C": np.linspace(0, 1, 5),
    "midpoint": np.linspace(100, 200, 4),

    # Learning rate
    "eta": np.linspace(0, 1, 5),

    # Discounting factor
    "gamma": np.linspace(0, 1, 8),

    # Balance between RPE and absolute rewards
    "alpha": np.linspace(0, 1, 5),

    # Negativity bias
    "kappa": np.linspace(1, 5, 5),
}

# We batch-run all parameter combinations.
# Because the model is stochastic, we run each combination multiple times
# (e.g., five iterations) to estimate the expected behavior.
# Seeding works as follows: each iteration is assigned a unique seed,
# and that same seed is used for all parameter combinations within that iteration.
# This ensures reproducibility while allowing multiple stochastic replications
# per parameter set.
rng = np.random.default_rng(12345)
seed_values = rng.integers(0, sys.maxsize, size=(n_iterations,))

for iteration, seed_value in enumerate(seed_values):
    print(f"Starting iteration {iteration}...", end="", flush=True)

    results = batch_run(
        model.IrritabilityModel,
        parameters=init_variables,
        data_collection_period=1,  # collect data for every step
        number_processes=16,
        rng=seed_value,
        max_steps=200,
    )

    results_df = pd.DataFrame(results)
    results_df["iteration"] = iteration

    # Sorting allows for row-based aggregation later
    results_df = results_df.sort_values(group_cols, ignore_index=True)

    results_df.to_parquet(f"output/004_action_readiness_{iteration}.parquet")

    del results
    del results_df
    gc.collect()

    print(f"Starting iteration {iteration}... done.")

# Quick test of sorting
df7 = pd.read_parquet("output/004_action_readiness_7.parquet", columns=group_cols)
df14 = pd.read_parquet("output/004_action_readiness_14.parquet", columns=group_cols)
assert df7.equals(df14), "Rows do not align after sorting!"

del df7, df14
gc.collect()
# Out:
# Starting iteration 0...
#   0%|          | 0/200000 [00:00<?, ?it/s]
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# /home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py:103: UserWarning: Random number generator not specified, this can make models non-reproducible. Please pass a random number generator explicitly
#   super().__init__(capacity=capacity, random=random, cell_klass=cell_klass)
# Process SpawnPoolWorker-16:
# Process SpawnPoolWorker-12:
# Process SpawnPoolWorker-11:
# Process SpawnPoolWorker-15:
# Process SpawnPoolWorker-9:
# Process SpawnPoolWorker-7:
# Process SpawnPoolWorker-10:
# Process SpawnPoolWorker-3:
# Process SpawnPoolWorker-8:
# Process SpawnPoolWorker-6:
# Process SpawnPoolWorker-2:
# Traceback (most recent call last):
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
# Process SpawnPoolWorker-4:
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 220, in _model_run_func
#     {
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 206, in _model_run_func
#     model.step()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/model.py", line 137, in _wrapped_step
#     self._user_step(*args, **kwargs)
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/model.py", line 77, in step
#     def step(self):
#
# KeyboardInterrupt
# Process SpawnPoolWorker-14:
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 204, in _model_run_func
#     model = model_cls(**kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/model.py", line 52, in __init__
#     self.grid = OrthogonalMooreGrid(
#                 ^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py", line 124, in __init__
#     self._connect_cells()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py", line 129, in _connect_cells
#     self._connect_cells_2d()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py", line 226, in _connect_cells_2d
#     self._connect_single_cell_2d(cell, offsets)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/discrete_space/grid.py", line 185, in _connect_single_cell_2d
#     cell.connect(self._cells[ni, nj], (di, dj))
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 206, in _model_run_func
#     model.step()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/model.py", line 137, in _wrapped_step
#     self._user_step(*args, **kwargs)
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/model.py", line 82, in step
#     self.agents.shuffle_do("update_emotions_and_learn")
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/agent.py", line 351, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 206, in _model_run_func
#     model.step()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/model.py", line 137, in _wrapped_step
#     self._user_step(*args, **kwargs)
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/model.py", line 80, in step
#     self.datacollector.collect(self)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/datacollection.py", line 385, in collect
#     self._agent_records[model.time] = list(agent_records)
#                                       ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/datacollection.py", line 316, in get_reports
#     return _prefix + tuple(reports)
#                      ^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 206, in _model_run_func
#     model.step()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/model.py", line 137, in _wrapped_step
#     self._user_step(*args, **kwargs)
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/model.py", line 78, in step
#     self.agents.shuffle_do("act")
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/agent.py", line 351, in shuffle_do
#     getattr(agent, method)(*args, **kwargs)
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/agents.py", line 79, in act
#     reward = self.get_reward()
#              ^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/projects/formal_model_irritability/simulations/004_action_readiness/agents.py", line 103, in get_reward
#     return 0.5 if self.random.random() < 0.40 else -0.5
#                   ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/agent.py", line 133, in random
#     @property
#
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 215, in _model_run_func
#     model_data, all_agents_data = _collect_data(model, step)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/site-packages/mesa/batchrunner.py", line 305, in _collect_data
#     agent_dict.update(zip(dc.agent_reporters, data[2:]))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Process SpawnPoolWorker-13:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 393, in put
#     obj = _ForkingPickler.dumps(obj)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 393, in put
#     obj = _ForkingPickler.dumps(obj)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# KeyboardInterrupt
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 398, in put
#     with self._wlock:
#          ^^^^^^^^^^^
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/pool.py", line 131, in worker
#     put((job, i, result))
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/queues.py", line 399, in put
#     self._writer.send_bytes(obj)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/connection.py", line 420, in _send_bytes
#     self._send(header)
#   File "/home/soelderer/.conda/envs/irritability_simulations/lib/python3.12/multiprocessing/connection.py", line 384, in _send
#     n = write(self._handle, buf)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# ## Summary (expectation and standard errors)

# %%
import numpy as np

value_cols = ["V", "M_A", "M_S"]

n_rows = len(pd.read_parquet("output/004_action_readiness_0.parquet"))
n = 0
mean = {col: np.zeros(n_rows) for col in value_cols}
M2 = {col: np.zeros(n_rows) for col in value_cols}

for i in range(n_iterations):
    path = f"output/004_action_readiness_{i}.parquet"

    print(f"Processing iteration {i}...")

    df = pd.read_parquet(path, columns=value_cols)
    n += 1
    for c in value_cols:
        x = df[c].to_numpy()
        delta = x - mean[c]
        mean[c] += delta / n
        M2[c] += delta * (x - mean[c])

# final standard deviation
std = {c: np.sqrt(M2[c] / (n - 1)) for c in value_cols}

df = pd.read_parquet(
    "output/004_action_readiness_0.parquet",
    columns=group_cols
)

summary = df.copy()

for c in value_cols:
    summary[f"{c}_mean"] = mean[c]
    summary[f"{c}_std"] = std[c]

summary.to_parquet("output/004_action_readiness_summary.parquet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 import numpy as np
#       3 value_cols = ["V", "M_A", "M_S"]
# ----> 5 n_rows = len(pd.read_parquet("output/004_action_readiness_0.parquet"))
#       6 n = 0
#       7 mean = {col: np.zeros(n_rows) for col in value_cols}
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Downcast data for dashboard

# %%
import pandas as pd
import gc

# Summary dataframe

summary = pd.read_parquet("output/004_action_readiness_summary.parquet")

summary.info(memory_usage="deep")

for c in summary.select_dtypes(include="integer"):
    summary[c] = pd.to_numeric(summary[c], downcast="integer")

for c in summary.select_dtypes(include="float"):
    summary[c] = pd.to_numeric(summary[c], downcast="float")

summary.info(memory_usage="deep")

summary.to_parquet("output/dashboard/004_action_readiness_summary.parquet")

# Write meta-info
lambda_A_vals = sorted(summary["lambda_A"].unique())
lambda_C_vals = sorted(summary["lambda_C"].unique())
midpoint_vals = sorted(summary["midpoint"].unique())
eta_vals      = sorted(summary["eta"].unique())
gamma_vals    = sorted(summary["gamma"].unique())
C_vals        = sorted(summary["C"].unique())
alpha_vals        = sorted(summary["alpha"].unique())
kappa_vals        = sorted(summary["kappa"].unique())

meta_df = pd.DataFrame({
    "n_iterations": [n_iterations],
    "lambda_A_vals": [lambda_A_vals],
    "eta_vals": [eta_vals],
    "gamma_vals": [gamma_vals],
    "C_vals": [C_vals],
    "alpha_vals": [alpha_vals],
    "kappa_vals": [kappa_vals],
    "lambda_C_vals": [lambda_C_vals],
    "midpoint_vals": [midpoint_vals],
})

# Write to parquet
meta_df.to_parquet("output/dashboard/meta_info.parquet",
                   engine="pyarrow")

del summary
gc.collect()

# Individual iterations
n_iterations_dashboard = 3  # not all iterations to save memory

for i in range(n_iterations_dashboard):
    print("-------------------------------------------------------------------")

    df = pd.read_parquet(f"output/004_action_readiness_{i}.parquet")

    df.info(memory_usage="deep")

    df.drop(columns=["AgentID", "RunId", "iteration", "r", "rpe", "seed"],
            inplace=True)

    for c in df.select_dtypes(include="integer"):
        df[c] = pd.to_numeric(df[c], downcast="integer")

    for c in df.select_dtypes(include="float"):
        df[c] = pd.to_numeric(df[c], downcast="float")

    df.info(memory_usage="deep")

    df.to_parquet(f"output/dashboard/004_action_readiness_{i}.parquet")

    del df
    gc.collect()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 15 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   lambda_A  float64
#  1   lambda_C  float64
#  2   midpoint  float64
#  3   C         float64
#  4   eta       float64
#  5   gamma     float64
#  6   alpha     float64
#  7   kappa     float64
#  8   Step      int64
#  9   V_mean    float64
#  10  V_std     float64
#  11  M_A_mean  float64
#  12  M_A_std   float64
#  13  M_S_mean  float64
#  14  M_S_std   float64
# dtypes: float64(14), int64(1)
# memory usage: 4.5 GB
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 15 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   lambda_A  float32
#  1   lambda_C  float32
#  2   midpoint  float32
#  3   C         float32
#  4   eta       float32
#  5   gamma     float32
#  6   alpha     float32
#  7   kappa     float32
#  8   Step      int16
#  9   V_mean    float32
#  10  V_std     float32
#  11  M_A_mean  float32
#  12  M_A_std   float32
#  13  M_S_mean  float32
#  14  M_S_std   float32
# dtypes: float32(14), int16(1)
# memory usage: 2.2 GB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 18 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   RunId      int64
#  1   iteration  int64
#  2   Step       int64
#  3   V          float64
#  4   M_A        float64
#  5   M_S        float64
#  6   r          float64
#  7   rpe        float64
#  8   C          float64
#  9   lambda_A   float64
#  10  lambda_C   float64
#  11  midpoint   float64
#  12  eta        float64
#  13  gamma      float64
#  14  alpha      float64
#  15  kappa      float64
#  16  seed       int64
#  17  AgentID    float64
# dtypes: float64(14), int64(4)
# memory usage: 5.4 GB
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 12 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Step      int16
#  1   V         float32
#  2   M_A       float32
#  3   M_S       float32
#  4   C         float32
#  5   lambda_A  float32
#  6   lambda_C  float32
#  7   midpoint  float32
#  8   eta       float32
#  9   gamma     float32
#  10  alpha     float32
#  11  kappa     float32
# dtypes: float32(11), int16(1)
# memory usage: 1.7 GB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 18 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   RunId      int64
#  1   iteration  int64
#  2   Step       int64
#  3   V          float64
#  4   M_A        float64
#  5   M_S        float64
#  6   r          float64
#  7   rpe        float64
#  8   C          float64
#  9   lambda_A   float64
#  10  lambda_C   float64
#  11  midpoint   float64
#  12  eta        float64
#  13  gamma      float64
#  14  alpha      float64
#  15  kappa      float64
#  16  seed       int64
#  17  AgentID    float64
# dtypes: float64(14), int64(4)
# memory usage: 5.4 GB
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 12 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Step      int16
#  1   V         float32
#  2   M_A       float32
#  3   M_S       float32
#  4   C         float32
#  5   lambda_A  float32
#  6   lambda_C  float32
#  7   midpoint  float32
#  8   eta       float32
#  9   gamma     float32
#  10  alpha     float32
#  11  kappa     float32
# dtypes: float32(11), int16(1)
# memory usage: 1.7 GB
# -------------------------------------------------------------------
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 18 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   RunId      int64
#  1   iteration  int64
#  2   Step       int64
#  3   V          float64
#  4   M_A        float64
#  5   M_S        float64
#  6   r          float64
#  7   rpe        float64
#  8   C          float64
#  9   lambda_A   float64
#  10  lambda_C   float64
#  11  midpoint   float64
#  12  eta        float64
#  13  gamma      float64
#  14  alpha      float64
#  15  kappa      float64
#  16  seed       int64
#  17  AgentID    float64
# dtypes: float64(14), int64(4)
# memory usage: 5.4 GB
# <class 'pandas.DataFrame'>
# RangeIndex: 40200000 entries, 0 to 40199999
# Data columns (total 12 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   Step      int16
#  1   V         float32
#  2   M_A       float32
#  3   M_S       float32
#  4   C         float32
#  5   lambda_A  float32
#  6   lambda_C  float32
#  7   midpoint  float32
#  8   eta       float32
#  9   gamma     float32
#  10  alpha     float32
#  11  kappa     float32
# dtypes: float32(11), int16(1)
# memory usage: 1.7 GB

# %% [markdown]
# # A glimpse at the data

# %%
print(results_df["C"].unique())

# results1 = results_df[results_df["RunId"] == 230]

# gamma = 0.57894737
# eta = 0.05263158
# lambda_A = 0.15789474
# C = 1

results1 = results_df[
    np.isclose(results_df["gamma"], 0.57894737) &
    np.isclose(results_df["eta"], 0.05263158) &
    np.isclose(results_df["lambda_A"], 0.84210526) &
    np.isclose(results_df["C"], 1)
]

# print(results_df.loc[22826, "eta"], repr(results_df.loc[22826, "eta"]))
# print(results_df.loc[22826, "lambda_A"], repr(results_df.loc[22826, "lambda_A"]))
# print(results_df.loc[22826, "C"], repr(results_df.loc[22826, "C"]))

# print(results_df["gamma"].dtype)


# results1.head(n=200)

# Prior to the first step, many things are not defined (e.g. action)
# results_df = results_df[results_df["Step"] > 0]

# results_df.head(n=200)

# results_df.columns

# %% [markdown]
# # Some plots

# %%
g = sns.lineplot(data=results1,
                 y="V",
                 x="Step",
                 label="Value of state")

g = sns.lineplot(data=results1,
                 y=results1["M_A"],
                 x="Step",
                 color="Orange",
                 label="Anger/frustration")

# g.set(title="Anger and aggressive action",
#       ylabel="Value");
plt.axhline(y=0, color='black', linewidth=1)
plt.axvline(x=100, color='black', linewidth=1, linestyle="--")

# plt.xlim(0, 130)
# plt.ylim(0, 1)
plt.show()
